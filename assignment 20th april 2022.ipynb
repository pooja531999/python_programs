# %%
 import pandas as pd

# %%
df = pd.read_csv('Mobilr_data.csv')

# %%
df
# Out:
#      Unnamed: 0                    name Device Type Sim Capability  \
# 0             0               Realme 8i  Smartphone       Dual-SIM
# 1             1            Realme 8s 5G  Smartphone       Dual-SIM
# 2             2   Xiaomi Redmi 10 Prime  Smartphone       Dual-SIM
# 3             3  Samsung Galaxy A52s 5G  Smartphone       Dual-SIM
# 4             4   Samsung Galaxy M32 5G  Smartphone       Dual-SIM
# ..          ...                     ...         ...            ...
# 145         145                Vivo Y11  Smartphone       Dual-SIM
# 146         146              Realme C11  Smartphone       Dual-SIM
# 147         147             Poco M2 Pro  Smartphone       Dual-SIM
# 148         148            OnePlus Nord  Smartphone       Dual-SIM
# 149         149               Realme X3  Smartphone            NaN
#
#     Input Mechanism         Availability                            Software  \
# 0       Touchscreen   Available In India  realme UI 2.0  Based on Android 11
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                    name Device Type Sim Capability  \
# 0           0               Realme 8i  Smartphone       Dual-SIM
# 1           1            Realme 8s 5G  Smartphone       Dual-SIM
# 2           2   Xiaomi Redmi 10 Prime  Smartphone       Dual-SIM
# 3           3  Samsung Galaxy A52s 5G  Smartphone       Dual-SIM
# 4           4   Samsung Galaxy M32 5G  Smartphone       Dual-SIM
#
#   Input Mechanism         Availability                            Software  \
# 0     Touchscreen   Available In India  realme UI 2.0  Based on Android 11
# 1     Touchscreen   Available In India  realme UI 2.0  Based on Android 11
# 2     Touchscreen   Available In India       MIUI 12.5 based on Android 11
# 3     Touchscreen   Available In India                          Android 11
# 4     Touchscreen   Available In India                          Android 11
#
#                    Processor Internal Memory Internal Storage  ...  \
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0          name Device Type Sim Capability Input Mechanism  \
# 145         145      Vivo Y11  Smartphone       Dual-SIM     Touchscreen
# 146         146    Realme C11  Smartphone       Dual-SIM     Touchscreen
# 147         147   Poco M2 Pro  Smartphone       Dual-SIM     Touchscreen
# 148         148  OnePlus Nord  Smartphone       Dual-SIM     Touchscreen
# 149         149     Realme X3  Smartphone            NaN          QWERTY
#
#             Availability                          Software  \
# 145   Available In India  Funtouch OS 9 Based on Android 9
# 146   Available In India     Realme UI Based on Android 10
# 147   Available In India       MIUI 11 based on Android 10
# 148   Available In India      OxygenOS based on Android 10
# 149   Available in India                        Android 10
#
#                          Processor Internal Memory Internal Storage  ...  \
# 145        Qualcomm Snapdragon 439           3GB               32GB  ...
# ...

# %%
df.isnull().head()
# Out:
#    Unnamed: 0   name  Device Type  Sim Capability  Input Mechanism  \
# 0       False  False        False           False            False
# 1       False  False        False           False            False
# 2       False  False        False           False            False
# 3       False  False        False           False            False
# 4       False  False        False           False            False
#
#    Availability  Software  Processor  Internal Memory  Internal Storage  ...  \
# 0         False     False      False            False             False  ...
# 1         False     False      False            False             False  ...
# 2         False     False      False            False             False  ...
# 3         False     False      False            False             False  ...
# 4         False     False      False            False             False  ...
#
#    Fast Charging  Wireless Charging  Network Type  Network Capability  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# name                         0
# Device Type                  1
# Sim Capability               3
# Input Mechanism              0
# Availability                 1
# Software                     1
# Processor                    1
# Internal Memory              2
# Internal Storage             2
# Dedicated Micro SD Card      3
# 3.5 mm Jack                  9
# Display Technology           2
# Display Size                 0
# Display Resolution           1
# Main Camera                  3
# Main Camera resolution       0
# Front Camera                 0
# Front Camera Resolution      3
# Battery Capacity             0
# USB Type                     3
# Fast Charging                2
# Wireless Charging            2
# Network Type                 0
# Network Capability           0
# Fingerprint Sensor           6
# Face Unlock                  3
# price                        0
# IP Rating                  139
# SD Card Capacity           112
# ...

# %%
df.isnull().sum().sum()
# Out:
# 448

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'Device Type', 'Sim Capability',
#        'Input Mechanism', 'Availability', 'Software', 'Processor',
#        'Internal Memory', 'Internal Storage', 'Dedicated Micro SD Card',
#        '3.5 mm Jack', 'Display Technology', 'Display Size',
#        'Display Resolution', 'Main Camera', 'Main Camera resolution',
#        'Front Camera', 'Front Camera Resolution', 'Battery Capacity',
#        'USB Type', 'Fast Charging', 'Wireless Charging', 'Network Type',
#        'Network Capability', 'Fingerprint Sensor', 'Face Unlock', 'price',
#        'IP Rating', 'SD Card Capacity', 'Dual Sim Capability'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               150 non-null    int64
#  1   name                     150 non-null    object
#  2   Device Type              149 non-null    object
#  3   Sim Capability           147 non-null    object
#  4   Input Mechanism          150 non-null    object
#  5   Availability             149 non-null    object
#  6   Software                 149 non-null    object
#  7   Processor                149 non-null    object
#  8   Internal Memory          148 non-null    object
#  9   Internal Storage         148 non-null    object
#  10  Dedicated Micro SD Card  147 non-null    object
#  11  3.5 mm Jack              141 non-null    object
#  12  Display Technology       148 non-null    object
#  13  Display Size             150 non-null    object
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0
# count  150.000000
# mean    74.500000
# std     43.445368
# min      0.000000
# 25%     37.250000
# 50%     74.500000
# 75%    111.750000
# max    149.000000

# %%
df['USB Type'].mode()
# Out:
# 0    USB Type-C
# dtype: object

# %%
df['IP Rating'].mode()
# Out:
# 0    IP68
# dtype: object
