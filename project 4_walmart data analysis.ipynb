# %% [markdown]
# Walmart Data Analysis
#
# Task is to analyze the sales of the walmart with the data given(eg. analysing weekly sales,which store or department
# sells most etc)
#
# Data Analysis and Data Visualization

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
train_df=pd.read_csv(r"C:\Users\pooja sinalkar\Downloads\train.csv")
test_df=pd.read_csv(r"C:\Users\pooja sinalkar\Downloads\test.csv")
features_df=pd.read_csv(r"C:\Users\pooja sinalkar\Downloads\features.csv")
stores_df=pd.read_csv(r"C:\Users\pooja sinalkar\Downloads\stores.csv")

# %%
train_df.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %%
train_df.describe()
# Out:
#                Store           Dept   Weekly_Sales
# count  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123
# std        12.785297      30.492054   22711.183519
# min         1.000000       1.000000   -4988.940000
# 25%        11.000000      18.000000    2079.650000
# 50%        22.000000      37.000000    7612.030000
# 75%        33.000000      74.000000   20205.852500
# max        45.000000      99.000000  693099.360000

# %%
train_df.isnull().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# dtype: int64

# %%
test_df.head()
# Out:
#    Store  Dept        Date  IsHoliday
# 0      1     1  2012-11-02      False
# 1      1     1  2012-11-09      False
# 2      1     1  2012-11-16      False
# 3      1     1  2012-11-23       True
# 4      1     1  2012-11-30      False

# %%
test_df.describe()
# Out:
#                Store           Dept
# count  115064.000000  115064.000000
# mean       22.238207      44.339524
# std        12.809930      30.656410
# min         1.000000       1.000000
# 25%        11.000000      18.000000
# 50%        22.000000      37.000000
# 75%        33.000000      74.000000
# max        45.000000      99.000000

# %%
test_df.isnull().sum()
# Out:
# Store        0
# Dept         0
# Date         0
# IsHoliday    0
# dtype: int64

# %%
features_df.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
features_df.describe()
# Out:
#              Store  Temperature   Fuel_Price      MarkDown1      MarkDown2  \
# count  8190.000000  8190.000000  8190.000000    4032.000000    2921.000000
# mean     23.000000    59.356198     3.405992    7032.371786    3384.176594
# std      12.987966    18.678607     0.431337    9262.747448    8793.583016
# min       1.000000    -7.290000     2.472000   -2781.450000    -265.760000
# 25%      12.000000    45.902500     3.041000    1577.532500      68.880000
# 50%      23.000000    60.710000     3.513000    4743.580000     364.570000
# 75%      34.000000    73.880000     3.743000    8923.310000    2153.350000
# max      45.000000   101.950000     4.468000  103184.980000  104519.540000
#
#            MarkDown3     MarkDown4      MarkDown5          CPI  Unemployment
# count    3613.000000   3464.000000    4050.000000  7605.000000   7605.000000
# mean     1760.100180   3292.935886    4132.216422   172.460809      7.826821
# std     11276.462208   6792.329861   13086.690278    39.738346      1.877259
# min      -179.260000      0.220000    -185.170000   126.064000      3.684000
# 25%         6.600000    304.687500    1440.827500   132.364839      6.634000
# 50%        36.260000   1176.425000    2727.135000   182.764003      7.806000
# 75%       163.150000   3310.007500    4832.555000   213.932412      8.567000
# max    149483.310000  67474.850000  771448.100000   228.976456     14.313000

# %%
features_df.isnull().sum()
# Out:
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64

# %%
stores_df.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
stores_df.isnull().sum()
# Out:
# Store    0
# Type     0
# Size     0
# dtype: int64

# %%
dataset_m = features_df.merge(stores_df,how='inner',on='Store')
dataset_m.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday Type  \
# 0        NaN        NaN        NaN  211.096358         8.106      False    A
# 1        NaN        NaN        NaN  211.242170         8.106       True    A
# 2        NaN        NaN        NaN  211.289143         8.106      False    A
# 3        NaN        NaN        NaN  211.319643         8.106      False    A
# 4        NaN        NaN        NaN  211.350143         8.106      False    A
#
#      Size
# 0  151315
# 1  151315
# 2  151315
# 3  151315
# 4  151315

# %%
dataset_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8190 entries, 0 to 8189
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
#  12  Type          8190 non-null   object
#  13  Size          8190 non-null   int64
# dtypes: bool(1), float64(9), int64(2), object(2)
# memory usage: 903.8+ KB

# %%
from datetime import datetime
#converting date to datetime
dataset_m['Date']=pd.to_datetime(dataset_m['Date'])
train_df['Date']=pd.to_datetime(train_df['Date'])
test_df['Date']=pd.to_datetime(test_df['Date'])
#Extract week and year from the date and make them into new columns
dataset_m['week']=dataset_m.Date.dt.isocalendar().week
dataset_m['year']=dataset_m.Date.dt.isocalendar().year

# %%
dataset_m.tail()
# Out:
#       Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 8185     45 2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45 2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45 2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45 2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45 2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5  CPI  Unemployment  IsHoliday Type  \
# 8185       3.00    2449.97    3169.69  NaN           NaN      False    B
# 8186     582.74    5797.47    1514.93  NaN           NaN      False    B
# 8187      85.72     744.84    2150.36  NaN           NaN      False    B
# 8188     204.19     363.00    1059.46  NaN           NaN      False    B
# 8189       2.06      10.88    1864.57  NaN           NaN      False    B
#
#         Size  week  year
# 8185  118221    26  2013
# 8186  118221    27  2013
# 8187  118221    28  2013
# 8188  118221    29  2013
# 8189  118221    30  2013

# %% [markdown]
# Creating a new df by merging (inner) the train_df and the
# new dataframe dataset_m on store,date and isholiday columns
# and sorting the values by store,dapartment and date

# %%
train_df_1 = train_df.merge(dataset_m,how='inner',on=['Store','Date','IsHoliday']).sort_values(by=['Store','Dept','Date']).reset_index(drop=True)

# %%
train_df_1.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0      1     1 2010-02-05      24924.50      False        42.31       2.572
# 1      1     1 2010-02-12      46039.49       True        38.51       2.548
# 2      1     1 2010-02-19      41595.55      False        39.93       2.514
# 3      1     1 2010-02-26      19403.54      False        46.63       2.561
# 4      1     1 2010-03-05      21827.90      False        46.50       2.625
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0        NaN        NaN        NaN        NaN        NaN  211.096358
# 1        NaN        NaN        NaN        NaN        NaN  211.242170
# 2        NaN        NaN        NaN        NaN        NaN  211.289143
# 3        NaN        NaN        NaN        NaN        NaN  211.319643
# 4        NaN        NaN        NaN        NaN        NaN  211.350143
#
#    Unemployment Type    Size  week  year
# 0         8.106    A  151315     5  2010
# 1         8.106    A  151315     6  2010
# 2         8.106    A  151315     7  2010
# 3         8.106    A  151315     8  2010
# 4         8.106    A  151315     9  2010

# %% [markdown]
# #Visualization

# %%
#scatter plot

# %%
def scatter(train_df_1,column):
    #plot the figure
    plt.figure()
    #plot the scatter plot with data from the specified column in x axis and weekly sales in y axis
    plt.scatter(train_df_1[column],train_df_1['Weekly_Sales'])
    #give y label as weekly sales
    plt.ylabel('Weekly_Sales')
    #give x label as the column specified as parameter in the function
    plt.xlabel(column)

# %%
# plot scatter plot using the scatter function a scatter plot of weekly sales with respect to store
scatter(train_df_1,'Store')

# %%
# plot scatter plot using the scatter function a scatter plot of weekly sales with respect to department
scatter(train_df_1,'Dept')

# %% [markdown]
# 2)Line plots for weekly sales for each year

# %%
# Filtering out mean weekly sales for the year 2011
weekly_sales_2011 = train_df_1[train_df_1['year']==2011]['Weekly_Sales'].groupby(train_df_1['week']).mean()
#Plot a line plot with week on x axis and sales for that particular week of the filtered year in y axis
sns.lineplot(weekly_sales_2011.index,weekly_sales_2011.values,color='red')
# Out:
# C:\Users\pooja sinalkar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='week'>

# %% [markdown]
# Here in the last week the sale was higher

# %%
# Filtering out mean weekly sales for the year 2010
weekly_sales_2010 = train_df_1[train_df_1['year']==2010]['Weekly_Sales'].groupby(train_df_1['week']).mean()
#Plot a line plot with week on x axis and sales for that particular week of the filtered year in y axis
sns.lineplot(weekly_sales_2010.index,weekly_sales_2010.values,color='blue')
# Out:
# C:\Users\pooja sinalkar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='week'>

# %% [markdown]
# Here also in last week the sales was higher

# %%
# Filtering out mean weekly sales for the year 2012
weekly_sales_2012 = train_df_1[train_df_1['year']==2012]['Weekly_Sales'].groupby(train_df_1['week']).mean()
#Plot a line plot with week on x axis and sales for that particular week of the filtered year in y axis
sns.lineplot(weekly_sales_2012.index,weekly_sales_2012.values,color='g')
# Out:
# C:\Users\pooja sinalkar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='week'>

# %% [markdown]
# 3) Combine line plots for each year(2010,2011,2012)
# Plotting the weekly sales for years 2010,2011,2012) on a single plot to compare the sales values with respect to week on each of these specified year for comparing the weekly sales in each year

# %%
# ploting the figure
plt.figure(figsize=(20,10))
# ploting three lineplots for weekly sales for each year
sns.lineplot(weekly_sales_2010.index,weekly_sales_2010.values,color='blue')
sns.lineplot(weekly_sales_2011.index,weekly_sales_2011.values,color='red')
sns.lineplot(weekly_sales_2012.index,weekly_sales_2012.values,color='g')
plt.grid()

#plot labels and legends
plt.xticks(np.arange(1,60,1))
plt.title('Average weekly sales per year',fontsize=20)
plt.xlabel('week',fontsize=16)
plt.ylabel('sales',fontsize=16)
plt.legend(['2010','2011','2012'],fontsize=16)
plt.show()
# Out:
# C:\Users\pooja sinalkar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\pooja sinalkar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\pooja sinalkar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# 4)Histogram

# %%
sns.distplot(train_df_1['Weekly_Sales'],color='g')
# Out:
# C:\Users\pooja sinalkar\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weekly_Sales', ylabel='Density'>

# %%
# kartosis is measure of whether the data is heavy-tailed or light-tailed relative to normal distribution
train_df_1['Weekly_Sales'].kurt()
# Out:
# 21.49128990832619

# %%
# Bar chart on Data Frame
weekly_sales_store = train_df_1['Weekly_Sales'].groupby(train_df_1['Store']).mean()
weekly_sales_store.head()
# Out:
# Store
# 1    21710.543621
# 2    26898.070031
# 3     6373.033983
# 4    29161.210415
# 5     5053.415813
# Name: Weekly_Sales, dtype: float64

# %%
weekly_sales_store_df = pd.DataFrame(weekly_sales_store )

# %%
weekly_sales_store_df.sort_values('Weekly_Sales',ascending=False).style.bar(align='left',width=98,color='#FFD200')
# Out:
# <style  type="text/css" >
# #T_5f5c9_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 98.0%, transparent 98.0%);
#         }#T_5f5c9_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 96.6%, transparent 96.6%);
#         }#T_5f5c9_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 95.1%, transparent 95.1%);
#         }#T_5f5c9_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 89.4%, transparent 89.4%);
#         }#T_5f5c9_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 87.5%, transparent 87.5%);
#         }#T_5f5c9_row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 85.3%, transparent 85.3%);
#         }#T_5f5c9_row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 79.2%, transparent 79.2%);
#         }#T_5f5c9_row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 67.6%, transparent 67.6%);
#         }#T_5f5c9_row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 66.8%, transparent 66.8%);
#         }#T_5f5c9_row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 63.9%, transparent 63.9%);
#         }#T_5f5c9_row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 61.3%, transparent 61.3%);
#         }#T_5f5c9_row11_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 59.0%, transparent 59.0%);
#         }#T_5f5c9_row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 58.6%, transparent 58.6%);
#         }#T_5f5c9_row13_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 57.0%, transparent 57.0%);
#         }#T_5f5c9_row14_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 55.8%, transparent 55.8%);
#         }#T_5f5c9_row15_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 54.7%, transparent 54.7%);
#         }#T_5f5c9_row16_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 51.8%, transparent 51.8%);
#         }#T_5f5c9_row17_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 45.3%, transparent 45.3%);
#         }#T_5f5c9_row18_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 42.8%, transparent 42.8%);
#         }#T_5f5c9_row19_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 40.6%, transparent 40.6%);
#         }#T_5f5c9_row20_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 39.3%, transparent 39.3%);
#         }#T_5f5c9_row21_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 38.1%, transparent 38.1%);
#         }#T_5f5c9_row22_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 35.1%, transparent 35.1%);
#         }#T_5f5c9_row23_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 34.9%, transparent 34.9%);
#         }#T_5f5c9_row24_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 33.9%, transparent 33.9%);
#         }#T_5f5c9_row25_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 33.5%, transparent 33.5%);
#         }#T_5f5c9_row26_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 32.4%, transparent 32.4%);
#         }#T_5f5c9_row27_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 31.7%, transparent 31.7%);
#         }#T_5f5c9_row28_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 26.5%, transparent 26.5%);
#         }#T_5f5c9_row29_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 25.6%, transparent 25.6%);
#         }#T_5f5c9_row30_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 25.0%, transparent 25.0%);
#         }#T_5f5c9_row31_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 21.1%, transparent 21.1%);
#         }#T_5f5c9_row32_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 21.0%, transparent 21.0%);
#         }#T_5f5c9_row33_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 15.8%, transparent 15.8%);
#         }#T_5f5c9_row34_col0,#T_5f5c9_row35_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 14.9%, transparent 14.9%);
#         }#T_5f5c9_row36_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 14.2%, transparent 14.2%);
#         }#T_5f5c9_row37_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 13.2%, transparent 13.2%);
#         }#T_5f5c9_row38_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 12.4%, transparent 12.4%);
#         }#T_5f5c9_row39_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 11.3%, transparent 11.3%);
#         }#T_5f5c9_row40_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 9.8%, transparent 9.8%);
#         }#T_5f5c9_row41_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 5.3%, transparent 5.3%);
#         }#T_5f5c9_row42_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 3.9%, transparent 3.9%);
#         }#T_5f5c9_row43_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 2.7%, transparent 2.7%);
#         }#T_5f5c9_row44_col0{
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_5f5c9_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Weekly_Sales</th>    </tr>    <tr>        <th class="index_name level0" >Store</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5f5c9_level0_row0" class="row_heading level0 row0" >20</th>
#                         <td id="T_5f5c9_row0_col0" class="data row0 col0" >29508.301592</td>
#             </tr>
#             <tr>
#                         <th id="T_5f5c9_level0_row1" class="row_heading level0 row1" >4</th>
#                         <td id="T_5f5c9_row1_col0" class="data row1 col0" >29161.210415</td>
#             </tr>
#             <tr>
#                         <th id="T_5f5c9_level0_row2" class="r

# %% [markdown]
# it is observe that store 20 has highest weekly sales

# %%
weekly_sales_store_df.sort_values('Weekly_Sales').style.bar(align='left',width=98,color='#FFD200')
# Out:
# <style  type="text/css" >
# #T_f0f50_row0_col0{
#             width:  10em;
#              height:  80%;
#         }#T_f0f50_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 2.7%, transparent 2.7%);
#         }#T_f0f50_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 3.9%, transparent 3.9%);
#         }#T_f0f50_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 5.3%, transparent 5.3%);
#         }#T_f0f50_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 9.8%, transparent 9.8%);
#         }#T_f0f50_row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 11.3%, transparent 11.3%);
#         }#T_f0f50_row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 12.4%, transparent 12.4%);
#         }#T_f0f50_row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 13.2%, transparent 13.2%);
#         }#T_f0f50_row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 14.2%, transparent 14.2%);
#         }#T_f0f50_row9_col0,#T_f0f50_row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 14.9%, transparent 14.9%);
#         }#T_f0f50_row11_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 15.8%, transparent 15.8%);
#         }#T_f0f50_row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 21.0%, transparent 21.0%);
#         }#T_f0f50_row13_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 21.1%, transparent 21.1%);
#         }#T_f0f50_row14_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 25.0%, transparent 25.0%);
#         }#T_f0f50_row15_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 25.6%, transparent 25.6%);
#         }#T_f0f50_row16_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 26.5%, transparent 26.5%);
#         }#T_f0f50_row17_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 31.7%, transparent 31.7%);
#         }#T_f0f50_row18_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 32.4%, transparent 32.4%);
#         }#T_f0f50_row19_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 33.5%, transparent 33.5%);
#         }#T_f0f50_row20_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 33.9%, transparent 33.9%);
#         }#T_f0f50_row21_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 34.9%, transparent 34.9%);
#         }#T_f0f50_row22_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 35.1%, transparent 35.1%);
#         }#T_f0f50_row23_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 38.1%, transparent 38.1%);
#         }#T_f0f50_row24_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 39.3%, transparent 39.3%);
#         }#T_f0f50_row25_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 40.6%, transparent 40.6%);
#         }#T_f0f50_row26_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 42.8%, transparent 42.8%);
#         }#T_f0f50_row27_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 45.3%, transparent 45.3%);
#         }#T_f0f50_row28_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 51.8%, transparent 51.8%);
#         }#T_f0f50_row29_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 54.7%, transparent 54.7%);
#         }#T_f0f50_row30_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 55.8%, transparent 55.8%);
#         }#T_f0f50_row31_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 57.0%, transparent 57.0%);
#         }#T_f0f50_row32_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 58.6%, transparent 58.6%);
#         }#T_f0f50_row33_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 59.0%, transparent 59.0%);
#         }#T_f0f50_row34_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 61.3%, transparent 61.3%);
#         }#T_f0f50_row35_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 63.9%, transparent 63.9%);
#         }#T_f0f50_row36_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 66.8%, transparent 66.8%);
#         }#T_f0f50_row37_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 67.6%, transparent 67.6%);
#         }#T_f0f50_row38_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 79.2%, transparent 79.2%);
#         }#T_f0f50_row39_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 85.3%, transparent 85.3%);
#         }#T_f0f50_row40_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 87.5%, transparent 87.5%);
#         }#T_f0f50_row41_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 89.4%, transparent 89.4%);
#         }#T_f0f50_row42_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 95.1%, transparent 95.1%);
#         }#T_f0f50_row43_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 96.6%, transparent 96.6%);
#         }#T_f0f50_row44_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFD200 98.0%, transparent 98.0%);
#         }</style><table id="T_f0f50_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Weekly_Sales</th>    </tr>    <tr>        <th class="index_name level0" >Store</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f0f50_level0_row0" class="row_heading level0 row0" >5</th>
#                         <td id="T_f0f50_row0_col0" class="data row0 col0" >5053.415813</td>
#             </tr>
#             <tr>
#                         <th id="T_f0f50_level0_row1" class="row_heading level0 row1" >33</th>
#                         <td id="T_f0f50_row1_col0" class="data row1 col0" >5728.414053</td>
#             </tr>
#             <tr>
#                         <th id="T_f0f50_level0_row2" class="row

# %% [markdown]
# by descending order it is observe that store 5 has less weekly sales

# %% [markdown]
# plottting a bar graph with store number as x values and mean weekly sales for that store as y values

# %%
#plotting the figure
plt.figure(figsize=(25,12))
#create the barplot with stores in x axis and mean weekly sales as y value
sns.barplot(weekly_sales_store.index,weekly_sales_store.values,palette='dark')
plt.grid()
plt.title('Average weekly sales per store',fontsize=20)
plt.xlabel('Store number',fontsize=16)
plt.ylabel('Sales per store',fontsize=16)
plt.show()
# Out:
# C:\Users\pooja sinalkar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Grouping the train_df_1 by department and computing the mean of weekly_sales for each department

# %%
weekly_sales_dept=train_df_1['Weekly_Sales'].groupby(train_df_1['Dept']).mean()

# %%
weekly_sales_dept_df=pd.DataFrame(weekly_sales_dept)

# %%
weekly_sales_dept_df.head()
# Out:
#       Weekly_Sales
# Dept
# 1     19213.485088
# 2     43607.020113
# 3     11793.698516
# 4     25974.630238
# 5     21365.583515

# %%
# sorting the dataframe with respect to weekly sales in Descending order
weekly_sales_dept_df.sort_values("Weekly_Sales",ascending=False).style.bar(align='left',width=98)
# Out:
# <style  type="text/css" >
# #T_70dd5_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 98.0%, transparent 98.0%);
#         }#T_70dd5_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 91.0%, transparent 91.0%);
#         }#T_70dd5_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 79.6%, transparent 79.6%);
#         }#T_70dd5_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 65.9%, transparent 65.9%);
#         }#T_70dd5_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 59.2%, transparent 59.2%);
#         }#T_70dd5_row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 58.9%, transparent 58.9%);
#         }#T_70dd5_row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 58.5%, transparent 58.5%);
#         }#T_70dd5_row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 56.8%, transparent 56.8%);
#         }#T_70dd5_row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 43.9%, transparent 43.9%);
#         }#T_70dd5_row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 43.5%, transparent 43.5%);
#         }#T_70dd5_row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 40.0%, transparent 40.0%);
#         }#T_70dd5_row11_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 39.3%, transparent 39.3%);
#         }#T_70dd5_row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 35.2%, transparent 35.2%);
#         }#T_70dd5_row13_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.9%, transparent 33.9%);
#         }#T_70dd5_row14_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.5%, transparent 31.5%);
#         }#T_70dd5_row15_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.2%, transparent 31.2%);
#         }#T_70dd5_row16_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.6%, transparent 28.6%);
#         }#T_70dd5_row17_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 27.8%, transparent 27.8%);
#         }#T_70dd5_row18_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.3%, transparent 26.3%);
#         }#T_70dd5_row19_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.0%, transparent 26.0%);
#         }#T_70dd5_row20_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.0%, transparent 25.0%);
#         }#T_70dd5_row21_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 23.9%, transparent 23.9%);
#         }#T_70dd5_row22_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.4%, transparent 20.4%);
#         }#T_70dd5_row23_col0,#T_70dd5_row24_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.2%, transparent 20.2%);
#         }#T_70dd5_row25_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.8%, transparent 19.8%);
#         }#T_70dd5_row26_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.4%, transparent 19.4%);
#         }#T_70dd5_row27_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.9%, transparent 18.9%);
#         }#T_70dd5_row28_col0,#T_70dd5_row29_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.6%, transparent 18.6%);
#         }#T_70dd5_row30_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.0%, transparent 18.0%);
#         }#T_70dd5_row31_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 17.5%, transparent 17.5%);
#         }#T_70dd5_row32_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.9%, transparent 15.9%);
#         }#T_70dd5_row33_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.4%, transparent 15.4%);
#         }#T_70dd5_row34_col0,#T_70dd5_row35_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.0%, transparent 14.0%);
#         }#T_70dd5_row36_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.3%, transparent 13.3%);
#         }#T_70dd5_row37_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.7%, transparent 11.7%);
#         }#T_70dd5_row38_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.6%, transparent 10.6%);
#         }#T_70dd5_row39_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.0%, transparent 10.0%);
#         }#T_70dd5_row40_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.7%, transparent 9.7%);
#         }#T_70dd5_row41_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.6%, transparent 9.6%);
#         }#T_70dd5_row42_col0,#T_70dd5_row43_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.9%, transparent 8.9%);
#         }#T_70dd5_row44_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.4%, transparent 8.4%);
#         }#T_70dd5_row45_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.3%, transparent 8.3%);
#         }#T_70dd5_row46_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.5%, transparent 7.5%);
#         }#T_70dd5_row47_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.4%, transparent 7.4%);
#         }#T_70dd5_row48_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.2%, transparent 7.2%);
#         }#T_70dd5_row49_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.8%, transparent 6.8%);
#         }#T_70dd5_row50_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.5%, transparent 6.5%);
#         }#T_70dd5_row51_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.2%, transparent 6.2%);
#         }#T_70d

# %%
#ploting a figure
plt.figure(figsize=(25,12))
#create a bar plot with department in x axis and mean weekly sales for each store as y values
sns.barplot(weekly_sales_dept.index,weekly_sales_dept.values)
plt.grid()
plt.title('Average weekly sales per department')
plt.xlabel('Department')
plt.ylabel('Avg sales')
plt.show()
# Out:
# C:\Users\pooja sinalkar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#plotting the normal distribution where sales is greater than zero
train_sales = train_df_1[train_df_1['Weekly_Sales']>0]

train_lessthanzero = train_df_1[train_df_1['Weekly_Sales']<=0]
# Take natural log of data for sales more then zero
salesgreaterthanzero = np.log1p(train_sales['Weekly_Sales'])
sns.distplot(salesgreaterthanzero)
# Out:
# C:\Users\pooja sinalkar\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weekly_Sales', ylabel='Density'>

# %%
## heatmap
plt.figure(figsize=(25,15))
sns.heatmap(train_df_1.corr(),annot=True)
# Out:
# <AxesSubplot:>
